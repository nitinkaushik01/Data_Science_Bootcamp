# %% [markdown]
# ## Import Libraries

# %%
import requests
import pandas as pd
from prettytable import PrettyTable
import json

# %% [markdown]
# ## Create pretty table object

# %%
tableobj = PrettyTable()

# %% [markdown]
# ## Store API Key in a variable & concatenate it with API endpoint

# %%
KeyVal = '37d0d5d1-eca3-4739-8723-8b4dce81be2b'

api_endpoint = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest?CMC_PRO_API_KEY='
api_endpoint += KeyVal
api_endpoint
# Out:
# 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest?CMC_PRO_API_KEY=37d0d5d1-eca3-4739-8723-8b4dce81be2b'

# %% [markdown]
# ## Fetch data in JSON format

# %%
json_data = requests.get(api_endpoint).json()
cryptodata = json_data['data']

# %%
requests.get(api_endpoint).json()
# Out:
# {'data': [{'circulating_supply': 17660237,
#    'cmc_rank': 1,
#    'date_added': '2013-04-28T00:00:00.000Z',
#    'id': 1,
#    'last_updated': '2019-04-22T23:47:27.000Z',
#    'max_supply': 21000000,
#    'name': 'Bitcoin',
#    'num_market_pairs': 7301,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:27.000Z',
#      'market_cap': 95313420306.7183,
#      'percent_change_1h': -0.317202,
#      'percent_change_24h': 1.69057,
#      'percent_change_7d': 6.47191,
#      'price': 5397.06348826,
#      'volume_24h': 14597789543.2224}},
#    'slug': 'bitcoin',
#    'symbol': 'BTC',
#    'tags': ['mineable'],
#    'total_supply': 17660237},
#   {'circulating_supply': 105770449.1241,
#    'cmc_rank': 2,
#    'date_added': '2015-08-07T00:00:00.000Z',
#    'id': 1027,
#    'last_updated': '2019-04-22T23:47:19.000Z',
#    'max_supply': None,
#    'name': 'Ethereum',
#    'num_market_pairs': 5232,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:19.000Z',
#      'market_cap': 18187965664.19498,
#      'percent_change_1h': -0.500194,
#      'percent_change_24h': 1.1542,
#      'percent_change_7d': 6.45466,
#      'price': 171.956967327,
#      'volume_24h': 6088591934.37358}},
#    'slug': 'ethereum',
#    'symbol': 'ETH',
#    'tags': ['mineable'],
#    'total_supply': 105770449.1241},
#   {'circulating_supply': 42004966728,
#    'cmc_rank': 3,
#    'date_added': '2013-08-04T00:00:00.000Z',
#    'id': 52,
#    'last_updated': '2019-04-22T23:47:04.000Z',
#    'max_supply': 100000000000,
#    'name': 'XRP',
#    'num_market_pairs': 383,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:04.000Z',
#      'market_cap': 13612874990.1434,
#      'percent_change_1h': -0.33575,
#      'percent_change_24h': 0.699444,
#      'percent_change_7d': 1.1696,
#      'price': 0.324077747241,
#      'volume_24h': 1131457498.66725}},
#    'slug': 'ripple',
#    'symbol': 'XRP',
#    'tags': [],
#    'total_supply': 99991643723},
#   {'circulating_supply': 17743037.5,
#    'cmc_rank': 4,
#    'date_added': '2017-07-23T00:00:00.000Z',
#    'id': 1831,
#    'last_updated': '2019-04-22T23:47:05.000Z',
#    'max_supply': 21000000,
#    'name': 'Bitcoin Cash',
#    'num_market_pairs': 291,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:05.000Z',
#      'market_cap': 5203148753.219788,
#      'percent_change_1h': -0.55809,
#      'percent_change_24h': 0.999014,
#      'percent_change_7d': -6.30973,
#      'price': 293.250169438,
#      'volume_24h': 1186256786.11166}},
#    'slug': 'bitcoin-cash',
#    'symbol': 'BCH',
#    'tags': ['mineable'],
#    'total_supply': 17743037.5},
#   {'circulating_supply': 942750386.9502,
#    'cmc_rank': 5,
#    'date_added': '2017-07-01T00:00:00.000Z',
#    'id': 1765,
#    'last_updated': '2019-04-22T23:47:04.000Z',
#    'max_supply': None,
#    'name': 'EOS',
#    'num_market_pairs': 302,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:04.000Z',
#      'market_cap': 4950573430.946012,
#      'percent_change_1h': -0.620616,
#      'percent_change_24h': 0.380082,
#      'percent_change_7d': -2.05882,
#      'price': 5.25120275682,
#      'volume_24h': 1905929053.11266}},
#    'slug': 'eos',
#    'symbol': 'EOS',
#    'tags': [],
#    'total_supply': 1042750390.6093},
#   {'circulating_supply': 61457133.5909222,
#    'cmc_rank': 6,
#    'date_added': '2013-04-28T00:00:00.000Z',
#    'id': 2,
#    'last_updated': '2019-04-22T23:47:03.000Z',
#    'max_supply': 84000000,
#    'name': 'Litecoin',
#    'num_market_pairs': 554,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:03.000Z',
#      'market_cap': 4730458873.017418,
#      'percent_change_1h': -0.604737,
#      'percent_change_24h': -0.0179831,
#      'percent_change_7d': -2.06719,
#      'price': 76.9716808549,
#      'volume_24h': 2661905447.47869}},
#    'slug': 'litecoin',
#    'symbol': 'LTC',
#    'tags': ['mineable'],
#    'total_supply': 61457133.5909222},
#   {'circulating_supply': 141175490.242,
#    'cmc_rank': 7,
#    'date_added': '2017-07-25T00:00:00.000Z',
#    'id': 1839,
#    'last_updated': '2019-04-22T23:47:04.000Z',
#    'max_supply': None,
#    'name': 'Binance Coin',
#    'num_market_pairs': 147,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0xB8c77482e45F1F44dE1745F52C74426C631bDD52'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:04.000Z',
#      'market_cap': 3376799808.532189,
#      'percent_change_1h': 1.24167,
#      'percent_change_24h': -0.881553,
#      'percent_change_7d': 25.2103,
#      'price': 23.9191647413,
#      'volume_24h': 254574367.327893}},
#    'slug': 'binance-coin',
#    'symbol': 'BNB',
#    'tags': [],
#    'total_supply': 189175490.242},
#   {'circulating_supply': 2611788410.99801,
#    'cmc_rank': 8,
#    'date_added': '2015-02-25T00:00:00.000Z',
#    'id': 825,
#    'last_updated': '2019-04-22T23:47:14.000Z',
#    'max_supply': None,
#    'name': 'Tether',
#    'num_market_pairs': 2162,
#    'platform': {'id': 83,
#     'name': 'Omni',
#     'slug': 'omni',
#     'symbol': 'OMNI',
#     'token_address': '31'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:14.000Z',
#      'market_cap': 2626877729.5220456,
#      'percent_change_1h': -0.0797587,
#      'percent_change_24h': -0.0405882,
#      'percent_change_7d': 0.387913,
#      'price': 1.00577738934,
#      'volume_24h': 12385861614.5089}},
#    'slug': 'tether',
#    'symbol': 'USDT',
#    'tags': [],
#    'total_supply': 2750057493.36343},
#   {'circulating_supply': 19363613643.97,
#    'cmc_rank': 9,
#    'date_added': '2014-08-05T00:00:00.000Z',
#    'id': 512,
#    'last_updated': '2019-04-22T23:47:02.000Z',
#    'max_supply': None,
#    'name': 'Stellar',
#    'num_market_pairs': 243,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:02.000Z',
#      'market_cap': 2198341811.281035,
#      'percent_change_1h': -0.42448,
#      'percent_change_24h': 1.186,
#      'percent_change_7d': -0.140009,
#      'price': 0.113529522521,
#      'volume_24h': 246992462.678278}},
#    'slug': 'stellar',
#    'symbol': 'XLM',
#    'tags': [],
#    'total_supply': 104902369331.456},
#   {'circulating_supply': 25927070538,
#    'cmc_rank': 10,
#    'date_added': '2017-10-01T00:00:00.000Z',
#    'id': 2010,
#    'last_updated': '2019-04-22T23:47:05.000Z',
#    'max_supply': 45000000000,
#    'name': 'Cardano',
#    'num_market_pairs': 73,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:05.000Z',
#      'market_cap': 2027733512.7474627,
#      'percent_change_1h': -0.682056,
#      'percent_change_24h': 5.80652,
#      'percent_change_7d': -4.64445,
#      'price': 0.0782091254689,
#      'volume_24h': 90216692.3380895}},
#    'slug': 'cardano',
#    'symbol': 'ADA',
#    'tags': ['mineable'],
#    'total_supply': 31112483745},
#   {'circulating_supply': 66682072191.4,
#    'cmc_rank': 11,
#    'date_added': '2017-09-13T00:00:00.000Z',
#    'id': 1958,
#    'last_updated': '2019-04-22T23:47:06.000Z',
#    'max_supply': None,
#    'name': 'TRON',
#    'num_market_pairs': 212,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:06.000Z',
#      'market_cap': 1678853311.3009613,
#      'percent_change_1h': -0.188258,
#      'percent_change_24h': 0.648614,
#      'percent_change_7d': -4.66357,
#      'price': 0.0251769817003,
#      'volume_24h': 386855626.069812}},
#    'slug': 'tron',
#    'symbol': 'TRX',
#    'tags': ['mineable'],
#    'total_supply': 99281283754.3},
#   {'circulating_supply': 16933696.6322684,
#    'cmc_rank': 12,
#    'date_added': '2014-05-21T00:00:00.000Z',
#    'id': 328,
#    'last_updated': '2019-04-22T23:47:02.000Z',
#    'max_supply': None,
#    'name': 'Monero',
#    'num_market_pairs': 125,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:02.000Z',
#      'market_cap': 1161148783.7707014,
#      'percent_change_1h': -0.482308,
#      'percent_change_24h': 0.0723056,
#      'percent_change_7d': 6.18845,
#      'price': 68.5703074164,
#      'volume_24h': 106705124.771231}},
#    'slug': 'monero',
#    'symbol': 'XMR',
#    'tags': ['mineable'],
#    'total_supply': 16933696.6322684},
#   {'circulating_supply': 8764658.48481937,
#    'cmc_rank': 13,
#    'date_added': '2014-02-14T00:00:00.000Z',
#    'id': 131,
#    'last_updated': '2019-04-22T23:47:02.000Z',
#    'max_supply': 18900000,
#    'name': 'Dash',
#    'num_market_pairs': 220,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:02.000Z',
#      'market_cap': 1075091322.9058511,
#      'percent_change_1h': -0.207942,
#      'percent_change_24h': 0.955108,
#      'percent_change_7d': 3.53263,
#      'price': 122.662089432,
#      'volume_24h': 253264777.082828}},
#    'slug': 'dash',
#    'symbol': 'DASH',
#    'tags': ['mineable'],
#    'total_supply': 8764658.48481937},
#   {'circulating_supply': 17740823.4164168,
#    'cmc_rank': 14,
#    'date_added': '2018-11-09T00:00:00.000Z',
#    'id': 3602,
#    'last_updated': '2019-04-22T23:47:11.000Z',
#    'max_supply': 21000000,
#    'name': 'Bitcoin SV',
#    'num_market_pairs': 129,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:11.000Z',
#      'market_cap': 1024687409.7582287,
#      'percent_change_1h': -1.05904,
#      'percent_change_24h': 2.06828,
#      'percent_change_7d': -2.23708,
#      'price': 57.7587288767,
#      'volume_24h': 106468120.916592}},
#    'slug': 'bitcoin-sv',
#    'symbol': 'BSV',
#    'tags': ['mineable'],
#    'total_supply': 17740823.4164168},
#   {'circulating_supply': 661426940.355599,
#    'cmc_rank': 15,
#    'date_added': '2017-10-02T00:00:00.000Z',
#    'id': 2011,
#    'last_updated': '2019-04-22T23:47:04.000Z',
#    'max_supply': None,
#    'name': 'Tezos',
#    'num_market_pairs': 27,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:04.000Z',
#      'market_cap': 890998023.3857002,
#      'percent_change_1h': -0.135126,
#      'percent_change_24h': 1.3959,
#      'percent_change_7d': 25.8118,
#      'price': 1.34708456675,
#      'volume_24h': 5017543.30182222}},
#    'slug': 'tezos',
#    'symbol': 'XTZ',
#    'tags': [],
#    'total_supply': 791757525.927326},
#   {'circulating_supply': 2779530283,
#    'cmc_rank': 16,
#    'date_added': '2017-06-13T00:00:00.000Z',
#    'id': 1720,
#    'last_updated': '2019-04-22T23:47:03.000Z',
#    'max_supply': 2779530283,
#    'name': 'IOTA',
#    'num_market_pairs': 38,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:03.000Z',
#      'market_cap': 861813011.1260339,
#      'percent_change_1h': -0.0311584,
#      'percent_change_24h': 1.32395,
#      'percent_change_7d': 1.91012,
#      'price': 0.310057068418,
#      'volume_24h': 12030897.7300748}},
#    'slug': 'iota',
#    'symbol': 'MIOTA',
#    'tags': [],
#    'total_supply': 2779530283},
#   {'circulating_supply': 65000000,
#    'cmc_rank': 17,
#    'date_added': '2016-09-08T00:00:00.000Z',
#    'id': 1376,
#    'last_updated': '2019-04-22T23:47:02.000Z',
#    'max_supply': 100000000,
#    'name': 'NEO',
#    'num_market_pairs': 169,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:02.000Z',
#      'market_cap': 704104217.5504999,
#      'percent_change_1h': -0.402395,
#      'percent_change_24h': 2.8493,
#      'percent_change_7d': 1.04419,
#      'price': 10.8323725777,
#      'volume_24h': 251648899.746095}},
#    'slug': 'neo',
#    'symbol': 'NEO',
#    'tags': [],
#    'total_supply': 100000000},
#   {'circulating_supply': 109920245,
#    'cmc_rank': 18,
#    'date_added': '2016-07-24T00:00:00.000Z',
#    'id': 1321,
#    'last_updated': '2019-04-22T23:47:02.000Z',
#    'max_supply': 210000000,
#    'name': 'Ethereum Classic',
#    'num_market_pairs': 194,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:02.000Z',
#      'market_cap': 652602664.524653,
#      'percent_change_1h': -0.4477,
#      'percent_change_24h': 0.380075,
#      'percent_change_7d': -3.69471,
#      'price': 5.93705613124,
#      'volume_24h': 377221546.257137}},
#    'slug': 'ethereum-classic',
#    'symbol': 'ETC',
#    'tags': ['mineable'],
#    'total_supply': 109920245},
#   {'circulating_supply': 494854358,
#    'cmc_rank': 19,
#    'date_added': '2018-03-08T00:00:00.000Z',
#    'id': 2566,
#    'last_updated': '2019-04-22T23:47:07.000Z',
#    'max_supply': None,
#    'name': 'Ontology',
#    'num_market_pairs': 67,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:07.000Z',
#      'market_cap': 611442404.6424775,
#      'percent_change_1h': 0.197685,
#      'percent_change_24h': 0.432957,
#      'percent_change_7d': -4.45268,
#      'price': 1.23560072728,
#      'volume_24h': 84340767.940436}},
#    'slug': 'ontology',
#    'symbol': 'ONT',
#    'tags': [],
#    'total_supply': 1000000000},
#   {'circulating_supply': 1000000,
#    'cmc_rank': 20,
#    'date_added': '2017-01-29T00:00:00.000Z',
#    'id': 1518,
#    'last_updated': '2019-04-22T23:47:02.000Z',
#    'max_supply': None,
#    'name': 'Maker',
#    'num_market_pairs': 63,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x9f8f72aa9304c8b593d555f12ef6589cc3a579a2'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:02.000Z',
#      'market_cap': 606935282.684,
#      'percent_change_1h': -0.297029,
#      'percent_change_24h': 0.501945,
#      'percent_change_7d': -3.84754,
#      'price': 606.935282684,
#      'volume_24h': 1284369.41624076}},
#    'slug': 'maker',
#    'symbol': 'MKR',
#    'tags': [],
#    'total_supply': 1000000},
#   {'circulating_supply': 8999999999,
#    'cmc_rank': 21,
#    'date_added': '2015-04-01T00:00:00.000Z',
#    'id': 873,
#    'last_updated': '2019-04-22T23:47:01.000Z',
#    'max_supply': None,
#    'name': 'NEM',
#    'num_market_pairs': 92,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:01.000Z',
#      'market_cap': 576894448.0870007,
#      'percent_change_1h': -0.396172,
#      'percent_change_24h': 1.3081,
#      'percent_change_7d': -1.01458,
#      'price': 0.0640993831279,
#      'volume_24h': 17065928.1304008}},
#    'slug': 'nem',
#    'symbol': 'XEM',
#    'tags': [],
#    'total_supply': 8999999999},
#   {'circulating_supply': 1249941614.70849,
#    'cmc_rank': 22,
#    'date_added': '2017-06-01T00:00:00.000Z',
#    'id': 1697,
#    'last_updated': '2019-04-22T23:47:03.000Z',
#    'max_supply': None,
#    'name': 'Basic Attention Token',
#    'num_market_pairs': 97,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x0d8775f648430679a709e98d2b0cb6250d2887ef'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:03.000Z',
#      'market_cap': 497440265.76126397,
#      'percent_change_1h': -0.919546,
#      'percent_change_24h': -11.0795,
#      'percent_change_7d': 35.1759,
#      'price': 0.397970801122,
#      'volume_24h': 94027343.4987526}},
#    'slug': 'basic-attention-token',
#    'symbol': 'BAT',
#    'tags': [],
#    'total_supply': 1500000000},
#   {'circulating_supply': 6375706.25,
#    'cmc_rank': 23,
#    'date_added': '2016-10-29T00:00:00.000Z',
#    'id': 1437,
#    'last_updated': '2019-04-22T23:47:03.000Z',
#    'max_supply': None,
#    'name': 'Zcash',
#    'num_market_pairs': 175,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:03.000Z',
#      'market_cap': 441446989.4448957,
#      'percent_change_1h': -0.100295,
#      'percent_change_24h': 1.31995,
#      'percent_change_7d': 3.25565,
#      'price': 69.2389159938,
#      'volume_24h': 218346459.52044}},
#    'slug': 'zcash',
#    'symbol': 'ZEC',
#    'tags': ['mineable'],
#    'total_supply': 6375706.25},
#   {'circulating_supply': 5162100456.621,
#    'cmc_rank': 24,
#    'date_added': '2018-12-14T00:00:00.000Z',
#    'id': 3635,
#    'last_updated': '2019-04-22T23:47:10.000Z',
#    'max_supply': None,
#    'name': 'Crypto.com Chain',
#    'num_market_pairs': 12,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:10.000Z',
#      'market_cap': 422175812.9009403,
#      'percent_change_1h': 1.33221,
#      'percent_change_24h': -1.56452,
#      'percent_change_7d': 5.00595,
#      'price': 0.081783726692,
#      'volume_24h': 597771.183141572}},
#    'slug': 'crypto-com-chain',
#    'symbol': 'CRO',
#    'tags': [],
#    'total_supply': 100000000000},
#   {'circulating_supply': 55454734800,
#    'cmc_rank': 25,
#    'date_added': '2017-08-22T00:00:00.000Z',
#    'id': 3077,
#    'last_updated': '2019-04-22T23:47:09.000Z',
#    'max_supply': None,
#    'name': 'VeChain',
#    'num_market_pairs': 52,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:09.000Z',
#      'market_cap': 387534845.0662764,
#      'percent_change_1h': -0.201507,
#      'percent_change_24h': 2.52958,
#      'percent_change_7d': 2.63701,
#      'price': 0.00698830941062,
#      'volume_24h': 21460068.0378575}},
#    'slug': 'vechain',
#    'symbol': 'VET',
#    'tags': [],
#    'total_supply': 86712634466},
#   {'circulating_supply': 119197183928.408,
#    'cmc_rank': 26,
#    'date_added': '2013-12-15T00:00:00.000Z',
#    'id': 74,
#    'last_updated': '2019-04-22T23:47:04.000Z',
#    'max_supply': None,
#    'name': 'Dogecoin',
#    'num_market_pairs': 332,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:04.000Z',
#      'market_cap': 334486353.81123567,
#      'percent_change_1h': -0.217099,
#      'percent_change_24h': 1.77032,
#      'percent_change_7d': 0.422716,
#      'price': 0.0028061598671,
#      'volume_24h': 36536300.8701619}},
#    'slug': 'dogecoin',
#    'symbol': 'DOGE',
#    'tags': ['mineable'],
#    'total_supply': 119197183928.408},
#   {'circulating_supply': 17513923.589,
#    'cmc_rank': 27,
#    'date_added': '2017-10-23T00:00:00.000Z',
#    'id': 2083,
#    'last_updated': '2019-04-22T23:47:05.000Z',
#    'max_supply': 21000000,
#    'name': 'Bitcoin Gold',
#    'num_market_pairs': 76,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:05.000Z',
#      'market_cap': 296900097.2998548,
#      'percent_change_1h': -0.462889,
#      'percent_change_24h': 1.63017,
#      'percent_change_7d': 3.5097,
#      'price': 16.9522320793,
#      'volume_24h': 14929989.0836842}},
#    'slug': 'bitcoin-gold',
#    'symbol': 'BTG',
#    'tags': ['mineable'],
#    'total_supply': 17513923.589},
#   {'circulating_supply': 100000000,
#    'cmc_rank': 28,
#    'date_added': '2016-06-02T00:00:00.000Z',
#    'id': 1274,
#    'last_updated': '2019-04-22T23:47:02.000Z',
#    'max_supply': None,
#    'name': 'Waves',
#    'num_market_pairs': 128,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:02.000Z',
#      'market_cap': 263474361.60400003,
#      'percent_change_1h': -0.36707,
#      'percent_change_24h': 1.10463,
#      'percent_change_7d': 0.0805526,
#      'price': 2.63474361604,
#      'volume_24h': 17260392.4780134}},
#    'slug': 'waves',
#    'symbol': 'WAVES',
#    'tags': [],
#    'total_supply': 100000000},
#   {'circulating_supply': 140245398.245133,
#    'cmc_rank': 29,
#    'date_added': '2017-07-14T00:00:00.000Z',
#    'id': 1808,
#    'last_updated': '2019-04-22T23:47:04.000Z',
#    'max_supply': None,
#    'name': 'OmiseGO',
#    'num_market_pairs': 166,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0xd26114cd6EE289AccF82350c8d8487fedB8A0C07'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:04.000Z',
#      'market_cap': 262783820.71590886,
#      'percent_change_1h': -0.197946,
#      'percent_change_24h': 0.677225,
#      'percent_change_7d': 0.805817,
#      'price': 1.87374291067,
#      'volume_24h': 80642028.3451601}},
#    'slug': 'omisego',
#    'symbol': 'OMG',
#    'tags': [],
#    'total_supply': 140245398.245133},
#   {'circulating_supply': 251355512.502969,
#    'cmc_rank': 30,
#    'date_added': '2018-10-08T00:00:00.000Z',
#    'id': 3408,
#    'last_updated': '2019-04-22T23:47:10.000Z',
#    'max_supply': None,
#    'name': 'USD Coin',
#    'num_market_pairs': 138,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:10.000Z',
#      'market_cap': 252313572.66431755,
#      'percent_change_1h': -0.114355,
#      'percent_change_24h': 0.218275,
#      'percent_change_7d': 0.319057,
#      'price': 1.0038115741,
#      'volume_24h': 46579222.7613071}},
#    'slug': 'usd-coin',
#    'symbol': 'USDC',
#    'tags': [],
#    'total_supply': 252277143.51},
#   {'circulating_supply': 11000000,
#    'cmc_rank': 31,
#    'date_added': '2015-10-27T00:00:00.000Z',
#    'id': 1104,
#    'last_updated': '2019-04-22T23:47:02.000Z',
#    'max_supply': None,
#    'name': 'Augur',
#    'num_market_pairs': 67,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x1985365e9f78359a9b6ad760e32412f4a445e862'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:02.000Z',
#      'market_cap': 251071320.0347,
#      'percent_change_1h': 1.47339,
#      'percent_change_24h': 9.63031,
#      'percent_change_7d': 20.5468,
#      'price': 22.8246654577,
#      'volume_24h': 16383763.0480063}},
#    'slug': 'augur',
#    'symbol': 'REP',
#    'tags': [],
#    'total_supply': 11000000},
#   {'circulating_supply': 9667331.382925,
#    'cmc_rank': 32,
#    'date_added': '2016-02-10T00:00:00.000Z',
#    'id': 1168,
#    'last_updated': '2019-04-22T23:47:02.000Z',
#    'max_supply': 21000000,
#    'name': 'Decred',
#    'num_market_pairs': 34,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:02.000Z',
#      'market_cap': 247915108.0511172,
#      'percent_change_1h': -0.146368,
#      'percent_change_24h': 0.95906,
#      'percent_change_7d': 6.15247,
#      'price': 25.6446270673,
#      'volume_24h': 1622379.14809992}},
#    'slug': 'decred',
#    'symbol': 'DCR',
#    'tags': ['mineable'],
#    'total_supply': 9667331.382925},
#   {'circulating_supply': 89416940,
#    'cmc_rank': 33,
#    'date_added': '2017-05-24T00:00:00.000Z',
#    'id': 1684,
#    'last_updated': '2019-04-22T23:47:04.000Z',
#    'max_supply': None,
#    'name': 'Qtum',
#    'num_market_pairs': 145,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:04.000Z',
#      'market_cap': 246974743.79072127,
#      'percent_change_1h': -0.691811,
#      'percent_change_24h': 1.74287,
#      'percent_change_7d': -2.5652,
#      'price': 2.76205765698,
#      'volume_24h': 118870268.435087}},
#    'slug': 'qtum',
#    'symbol': 'QTUM',
#    'tags': [],
#    'total_supply': 101416940},
#   {'circulating_supply': 133248289.1965,
#    'cmc_rank': 34,
#    'date_added': '2017-03-06T00:00:00.000Z',
#    'id': 1567,
#    'last_updated': '2019-04-22T23:47:02.000Z',
#    'max_supply': 133248290,
#    'name': 'Nano',
#    'num_market_pairs': 39,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:02.000Z',
#      'market_cap': 235356086.33926076,
#      'percent_change_1h': -0.03305,
#      'percent_change_24h': 5.00263,
#      'percent_change_7d': 17.057,
#      'price': 1.76629724673,
#      'volume_24h': 10545302.5921928}},
#    'slug': 'nano',
#    'symbol': 'NANO',
#    'tags': [],
#    'total_supply': 133248289.1965},
#   {'circulating_supply': 116356927.821928,
#    'cmc_rank': 35,
#    'date_added': '2016-04-06T00:00:00.000Z',
#    'id': 1214,
#    'last_updated': '2019-04-22T23:47:02.000Z',
#    'max_supply': None,
#    'name': 'Lisk',
#    'num_market_pairs': 58,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:02.000Z',
#      'market_cap': 233021419.52934137,
#      'percent_change_1h': -0.288085,
#      'percent_change_24h': 0.79709,
#      'percent_change_7d': 2.68244,
#      'price': 2.00264327953,
#      'volume_24h': 4776634.63422299}},
#    'slug': 'lisk',
#    'symbol': 'LSK',
#    'tags': [],
#    'total_supply': 131472058},
#   {'circulating_supply': 3381955000,
#    'cmc_rank': 36,
#    'date_added': '2018-03-10T00:00:00.000Z',
#    'id': 2577,
#    'last_updated': '2019-04-22T23:47:07.000Z',
#    'max_supply': 21000000000,
#    'name': 'Ravencoin',
#    'num_market_pairs': 29,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:07.000Z',
#      'market_cap': 209360265.32114986,
#      'percent_change_1h': -0.128346,
#      'percent_change_24h': -1.5881,
#      'percent_change_7d': 7.18947,
#      'price': 0.0619051008429,
#      'volume_24h': 12736966.7225289}},
#    'slug': 'ravencoin',
#    'symbol': 'RVN',
#    'tags': ['mineable'],
#    'total_supply': 3381955000},
#   {'circulating_supply': 199735069.55,
#    'cmc_rank': 37,
#    'date_added': '2018-03-06T00:00:00.000Z',
#    'id': 2563,
#    'last_updated': '2019-04-22T23:47:08.000Z',
#    'max_supply': None,
#    'name': 'TrueUSD',
#    'num_market_pairs': 159,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x0000000000085d4780B73119b644AE5ecd22b376'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:08.000Z',
#      'market_cap': 200434291.1699538,
#      'percent_change_1h': -0.159561,
#      'percent_change_24h': -0.166641,
#      'percent_change_7d': -0.0392471,
#      'price': 1.00350074537,
#      'volume_24h': 106146353.982889}},
#    'slug': 'trueusd',
#    'symbol': 'TUSD',
#    'tags': [],
#    'total_supply': 199735069.55},
#   {'circulating_supply': 186492897.953,
#    'cmc_rank': 38,
#    'date_added': '2017-11-24T00:00:00.000Z',
#    'id': 2222,
#    'last_updated': '2019-04-22T23:47:05.000Z',
#    'max_supply': 210000000,
#    'name': 'Bitcoin Diamond',
#    'num_market_pairs': 22,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:05.000Z',
#      'market_cap': 199476460.92918184,
#      'percent_change_1h': -0.127231,
#      'percent_change_24h': 1.15078,
#      'percent_change_7d': 0.458925,
#      'price': 1.06961961082,
#      'volume_24h': 3822225.76135812}},
#    'slug': 'bitcoin-diamond',
#    'symbol': 'BCD',
#    'tags': ['mineable'],
#    'total_supply': 189492897.953},
#   {'circulating_supply': 473406687.603972,
#    'cmc_rank': 39,
#    'date_added': '2017-10-27T00:00:00.000Z',
#    'id': 2099,
#    'last_updated': '2019-04-22T23:47:05.000Z',
#    'max_supply': None,
#    'name': 'ICON',
#    'num_market_pairs': 50,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:05.000Z',
#      'market_cap': 193170353.14042792,
#      'percent_change_1h': -2.13567,
#      'percent_change_24h': 13.1306,
#      'percent_change_7d': 14.0581,
#      'price': 0.408043143873,
#      'volume_24h': 31294542.7901695}},
#    'slug': 'icon',
#    'symbol': 'ICX',
#    'tags': [],
#    'total_supply': 800460000},
#   {'circulating_supply': 133214575156,
#    'cmc_rank': 40,
#    'date_added': '2018-04-29T00:00:00.000Z',
#    'id': 2682,
#    'last_updated': '2019-04-22T23:47:08.000Z',
#    'max_supply': None,
#    'name': 'Holo',
#    'num_market_pairs': 43,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x6c6ee5e31d828de241282b9606c8e98ea48526e2'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:08.000Z',
#      'market_cap': 185578096.18678695,
#      'percent_change_1h': -0.200972,
#      'percent_change_24h': 0.511277,
#      'percent_change_7d': 12.3916,
#      'price': 0.00139307651561,
#      'volume_24h': 10931218.9559196}},
#    'slug': 'holo',
#    'symbol': 'HOT',
#    'tags': [],
#    'total_supply': 177619433541.141},
#   {'circulating_supply': 587710996.56836,
#    'cmc_rank': 41,
#    'date_added': '2017-08-16T00:00:00.000Z',
#    'id': 1896,
#    'last_updated': '2019-04-22T23:47:04.000Z',
#    'max_supply': None,
#    'name': '0x',
#    'num_market_pairs': 149,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0xe41d2489571d322189246dafa5ebde1f4699f498'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:04.000Z',
#      'market_cap': 183781737.72376826,
#      'percent_change_1h': -0.486371,
#      'percent_change_24h': -0.346359,
#      'percent_change_7d': 0.819552,
#      'price': 0.312707672303,
#      'volume_24h': 17916371.8091867}},
#    'slug': '0x',
#    'symbol': 'ZRX',
#    'tags': [],
#    'total_supply': 1000000000},
#   {'circulating_supply': 8687760060.0875,
#    'cmc_rank': 42,
#    'date_added': '2018-01-25T00:00:00.000Z',
#    'id': 2469,
#    'last_updated': '2019-04-22T23:47:07.000Z',
#    'max_supply': None,
#    'name': 'Zilliqa',
#    'num_market_pairs': 97,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x05f4a42e251f2d52b8ed15e9fedaacfcef1fad27'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:07.000Z',
#      'market_cap': 182047100.87184668,
#      'percent_change_1h': -0.821721,
#      'percent_change_24h': -0.397037,
#      'percent_change_7d': 1.33599,
#      'price': 0.0209544347004,
#      'volume_24h': 12605065.8985074}},
#    'slug': 'zilliqa',
#    'symbol': 'ZIL',
#    'tags': [],
#    'total_supply': 12533442436.6081},
#   {'circulating_supply': 350000000,
#    'cmc_rank': 43,
#    'date_added': '2017-09-20T00:00:00.000Z',
#    'id': 1975,
#    'last_updated': '2019-04-22T23:47:04.000Z',
#    'max_supply': None,
#    'name': 'Chainlink',
#    'num_market_pairs': 46,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x514910771af9ca656af840dff83e8264ecf986ca'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:04.000Z',
#      'market_cap': 173993405.20450002,
#      'percent_change_1h': -0.296226,
#      'percent_change_24h': -0.303072,
#      'percent_change_7d': 0.621302,
#      'price': 0.49712401487,
#      'volume_24h': 5961484.72700882}},
#    'slug': 'chainlink',
#    'symbol': 'LINK',
#    'tags': [],
#    'total_supply': 1000000000},
#   {'circulating_supply': 184066828814.059,
#    'cmc_rank': 44,
#    'date_added': '2014-06-17T00:00:00.000Z',
#    'id': 372,
#    'last_updated': '2019-04-22T23:47:01.000Z',
#    'max_supply': 184470000000,
#    'name': 'Bytecoin',
#    'num_market_pairs': 12,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:01.000Z',
#      'market_cap': 165930116.12096614,
#      'percent_change_1h': -0.35443,
#      'percent_change_24h': 1.55639,
#      'percent_change_7d': 1.41818,
#      'price': 0.00090146669658,
#      'volume_24h': 160702.42397415}},
#    'slug': 'bytecoin-bcn',
#    'symbol': 'BCN',
#    'tags': ['mineable'],
#    'total_supply': 184066828814.059},
#   {'circulating_supply': 2710810000,
#    'cmc_rank': 45,
#    'date_added': '2014-07-21T00:00:00.000Z',
#    'id': 463,
#    'last_updated': '2019-04-22T23:47:01.000Z',
#    'max_supply': 3600570502,
#    'name': 'BitShares',
#    'num_market_pairs': 86,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:01.000Z',
#      'market_cap': 163422479.55813777,
#      'percent_change_1h': -2.07156,
#      'percent_change_24h': -1.7775,
#      'percent_change_7d': -1.24065,
#      'price': 0.0602854790849,
#      'volume_24h': 9789001.02140353}},
#    'slug': 'bitshares',
#    'symbol': 'BTS',
#    'tags': [],
#    'total_supply': 2710810000},
#   {'circulating_supply': 12013965608.8475,
#    'cmc_rank': 46,
#    'date_added': '2018-01-16T00:00:00.000Z',
#    'id': 2405,
#    'last_updated': '2019-04-22T23:47:06.000Z',
#    'max_supply': None,
#    'name': 'IOST',
#    'num_market_pairs': 65,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0xfa1a856cfa3409cfa145fa4e20eb270df3eb21ab'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:06.000Z',
#      'market_cap': 162504309.51562104,
#      'percent_change_1h': -0.626645,
#      'percent_change_24h': -2.38918,
#      'percent_change_7d': 5.6593,
#      'price': 0.0135262838938,
#      'volume_24h': 27279570.2105116}},
#    'slug': 'iostoken',
#    'symbol': 'IOST',
#    'tags': [],
#    'total_supply': 21000000000},
#   {'circulating_supply': 212116500000,
#    'cmc_rank': 47,
#    'date_added': '2019-01-31T00:00:00.000Z',
#    'id': 3718,
#    'last_updated': '2019-04-22T23:47:11.000Z',
#    'max_supply': None,
#    'name': 'BitTorrent',
#    'num_market_pairs': 89,
#    'platform': {'id': 1958,
#     'name': 'TRON',
#     'slug': 'tron',
#     'symbol': 'TRX',
#     'token_address': '1002000'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:11.000Z',
#      'market_cap': 152363867.31772345,
#      'percent_change_1h': 0.0341735,
#      'percent_change_24h': -0.367329,
#      'percent_change_7d': -3.52419,
#      'price': 0.000718302759652,
#      'volume_24h': 119751295.352471}},
#    'slug': 'bittorrent',
#    'symbol': 'BTT',
#    'tags': [],
#    'total_supply': 990000000000},
#   {'circulating_supply': 11705106797.0606,
#    'cmc_rank': 48,
#    'date_added': '2014-02-06T00:00:00.000Z',
#    'id': 109,
#    'last_updated': '2019-04-22T23:47:01.000Z',
#    'max_supply': 21000000000,
#    'name': 'DigiByte',
#    'num_market_pairs': 57,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:01.000Z',
#      'market_cap': 152088055.09843883,
#      'percent_change_1h': -0.829184,
#      'percent_change_24h': 1.7764,
#      'percent_change_7d': 0.994012,
#      'price': 0.0129933077703,
#      'volume_24h': 1339475.93927678}},
#    'slug': 'digibyte',
#    'symbol': 'DGB',
#    'tags': ['mineable'],
#    'total_supply': 11705106797.0606},
#   {'circulating_supply': 260479085.5,
#    'cmc_rank': 49,
#    'date_added': '2017-06-01T00:00:00.000Z',
#    'id': 1700,
#    'last_updated': '2019-04-22T23:47:03.000Z',
#    'max_supply': None,
#    'name': 'Aeternity',
#    'num_market_pairs': 58,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:03.000Z',
#      'market_cap': 146559265.56558272,
#      'percent_change_1h': -0.951107,
#      'percent_change_24h': 2.74642,
#      'percent_change_7d': 4.53089,
#      'price': 0.562652718487,
#      'volume_24h': 40687964.278797}},
#    'slug': 'aeternity',
#    'symbol': 'AE',
#    'tags': ['mineable'],
#    'total_supply': 306300029.49932},
#   {'circulating_supply': 767107985.064264,
#    'cmc_rank': 50,
#    'date_added': '2017-11-01T00:00:00.000Z',
#    'id': 2130,
#    'last_updated': '2019-04-22T23:47:05.000Z',
#    'max_supply': None,
#    'name': 'Enjin Coin',
#    'num_market_pairs': 45,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0xf629cbd94d3791c9250152bd8dfbdf380e2a3b9c'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:05.000Z',
#      'market_cap': 145534828.4059053,
#      'percent_change_1h': -0.444316,
#      'percent_change_24h': -0.417782,
#      'percent_change_7d': 24.9644,
#      'price': 0.189718828691,
#      'volume_24h': 15544257.5253825}},
#    'slug': 'enjin-coin',
#    'symbol': 'ENJ',
#    'tags': [],
#    'total_supply': 1000000000},
#   {'circulating_supply': 194603096087.921,
#    'cmc_rank': 51,
#    'date_added': '2018-03-22T00:00:00.000Z',
#    'id': 2603,
#    'last_updated': '2019-04-22T23:47:07.000Z',
#    'max_supply': None,
#    'name': 'Pundi X',
#    'num_market_pairs': 56,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0xa15c7ebe1f07caf6bff097d8a589fb8ac49ae5b3'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:07.000Z',
#      'market_cap': 135456898.6345738,
#      'percent_change_1h': 0.959633,
#      'percent_change_24h': 0.459797,
#      'percent_change_7d': 1.7042,
#      'price': 0.000696067541358,
#      'volume_24h': 4578617.49025702}},
#    'slug': 'pundi-x',
#    'symbol': 'NPXS',
#    'tags': [],
#    'total_supply': 274555193861},
#   {'circulating_supply': 15902356284.4511,
#    'cmc_rank': 52,
#    'date_added': '2014-10-25T00:00:00.000Z',
#    'id': 693,
#    'last_updated': '2019-04-22T23:47:01.000Z',
#    'max_supply': 16555000000,
#    'name': 'Verge',
#    'num_market_pairs': 56,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:01.000Z',
#      'market_cap': 134148428.79187343,
#      'percent_change_1h': -0.622744,
#      'percent_change_24h': 2.5405,
#      'percent_change_7d': 2.23653,
#      'price': 0.00843575797148,
#      'volume_24h': 2425314.54743121}},
#    'slug': 'verge',
#    'symbol': 'XVG',
#    'tags': ['mineable'],
#    'total_supply': 15902356284.4511},
#   {'circulating_supply': 311959178.319,
#    'cmc_rank': 53,
#    'date_added': '2016-04-18T00:00:00.000Z',
#    'id': 1230,
#    'last_updated': '2019-04-22T23:47:02.000Z',
#    'max_supply': None,
#    'name': 'Steem',
#    'num_market_pairs': 31,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:02.000Z',
#      'market_cap': 130132131.97015034,
#      'percent_change_1h': -0.0570775,
#      'percent_change_24h': 0.341144,
#      'percent_change_7d': 0.906882,
#      'price': 0.417144745256,
#      'volume_24h': 1046282.56565675}},
#    'slug': 'steem',
#    'symbol': 'STEEM',
#    'tags': [],
#    'total_supply': 328933272.319},
#   {'circulating_supply': 40388453259,
#    'cmc_rank': 54,
#    'date_added': '2015-08-26T00:00:00.000Z',
#    'id': 1042,
#    'last_updated': '2019-04-22T23:47:02.000Z',
#    'max_supply': None,
#    'name': 'Siacoin',
#    'num_market_pairs': 28,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:02.000Z',
#      'market_cap': 123322244.37542823,
#      'percent_change_1h': -0.802453,
#      'percent_change_24h': 3.87556,
#      'percent_change_7d': -0.726418,
#      'price': 0.00305340349591,
#      'volume_24h': 6815027.23990956}},
#    'slug': 'siacoin',
#    'symbol': 'SC',
#    'tags': ['mineable'],
#    'total_supply': 40388453259},
#   {'circulating_supply': 112905541.85915,
#    'cmc_rank': 55,
#    'date_added': '2017-02-05T00:00:00.000Z',
#    'id': 1521,
#    'last_updated': '2019-04-22T23:47:02.000Z',
#    'max_supply': 200000000,
#    'name': 'Komodo',
#    'num_market_pairs': 20,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:02.000Z',
#      'market_cap': 122936191.20668948,
#      'percent_change_1h': -0.726135,
#      'percent_change_24h': 0.568677,
#      'percent_change_7d': 5.4986,
#      'price': 1.08884107177,
#      'volume_24h': 832041.68922171}},
#    'slug': 'komodo',
#    'symbol': 'KMD',
#    'tags': ['mineable'],
#    'total_supply': 112905541.85915},
#   {'circulating_supply': 50000200,
#    'cmc_rank': 56,
#    'date_added': '2018-02-03T00:00:00.000Z',
#    'id': 2502,
#    'last_updated': '2019-04-22T23:47:07.000Z',
#    'max_supply': None,
#    'name': 'Huobi Token',
#    'num_market_pairs': 53,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x6f259637dcd74c767781e37bc6133cd6a68aa161'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:07.000Z',
#      'market_cap': 122746825.9083397,
#      'percent_change_1h': -0.720315,
#      'percent_change_24h': -0.439623,
#      'percent_change_7d': 7.89208,
#      'price': 2.45492669846,
#      'volume_24h': 87310765.006849}},
#    'slug': 'huobi-token',
#    'symbol': 'HT',
#    'tags': [],
#    'total_supply': 500000000},
#   {'circulating_supply': 1002499275,
#    'cmc_rank': 57,
#    'date_added': '2017-08-08T00:00:00.000Z',
#    'id': 1866,
#    'last_updated': '2019-04-22T23:47:04.000Z',
#    'max_supply': None,
#    'name': 'Bytom',
#    'num_market_pairs': 48,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:04.000Z',
#      'market_cap': 111108830.14823258,
#      'percent_change_1h': -0.311323,
#      'percent_change_24h': 0.457432,
#      'percent_change_7d': -7.11915,
#      'price': 0.110831830924,
#      'volume_24h': 8222797.17859974}},
#    'slug': 'bytom',
#    'symbol': 'BTM',
#    'tags': ['mineable'],
#    'total_supply': 1407000000},
#   {'circulating_supply': 6542330148.20859,
#    'cmc_rank': 58,
#    'date_added': '2018-06-26T00:00:00.000Z',
#    'id': 2874,
#    'last_updated': '2019-04-22T23:47:08.000Z',
#    'max_supply': None,
#    'name': 'Aurora',
#    'num_market_pairs': 11,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x9ab165d795019b6d8b3e971dda91071421305e5a'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:08.000Z',
#      'market_cap': 105965023.16396566,
#      'percent_change_1h': 0.627513,
#      'percent_change_24h': 0.58612,
#      'percent_change_7d': -2.82069,
#      'price': 0.0161968321322,
#      'volume_24h': 3302989.7044306}},
#    'slug': 'aurora',
#    'symbol': 'AOA',
#    'tags': [],
#    'total_supply': 10000000000},
#   {'circulating_supply': 1649000000,
#    'cmc_rank': 59,
#    'date_added': '2018-08-07T00:00:00.000Z',
#    'id': 3115,
#    'last_updated': '2019-04-22T23:47:09.000Z',
#    'max_supply': None,
#    'name': 'Maximine Coin',
#    'num_market_pairs': 7,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x8e766f57f7d16ca50b4a0b90b88f6468a09b0439'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:09.000Z',
#      'market_cap': 107743801.15271232,
#      'percent_change_1h': -1.82634,
#      'percent_change_24h': -9.21934,
#      'percent_change_7d': -18.5905,
#      'price': 0.0653388727427,
#      'volume_24h': 24072504.8965167}},
#    'slug': 'maximine-coin',
#    'symbol': 'MXM',
#    'tags': [],
#    'total_supply': 16000000000},
#   {'circulating_supply': 41112339.4106683,
#    'cmc_rank': 60,
#    'date_added': '2017-08-27T00:00:00.000Z',
#    'id': 1925,
#    'last_updated': '2019-04-22T23:47:04.000Z',
#    'max_supply': 100000000,
#    'name': 'Waltonchain',
#    'num_market_pairs': 32,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0xb7cb1c96db6b22b0d3d9536e0108d062bd488f74'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:04.000Z',
#      'market_cap': 106460311.91861834,
#      'percent_change_1h': -0.834141,
#      'percent_change_24h': 1.2348,
#      'percent_change_7d': 24.568,
#      'price': 2.58949778691,
#      'volume_24h': 5221032.00711451}},
#    'slug': 'waltonchain',
#    'symbol': 'WTC',
#    'tags': [],
#    'total_supply': 70000000},
#   {'circulating_supply': 89939916,
#    'cmc_rank': 61,
#    'date_added': '2017-10-24T00:00:00.000Z',
#    'id': 2087,
#    'last_updated': '2019-04-22T23:47:05.000Z',
#    'max_supply': None,
#    'name': 'KuCoin Shares',
#    'num_market_pairs': 12,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x039b5649a59967e3e936d7471f9c3700100ee1ab'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:05.000Z',
#      'market_cap': 106118877.07427238,
#      'percent_change_1h': -0.0936622,
#      'percent_change_24h': -0.366154,
#      'percent_change_7d': 4.15248,
#      'price': 1.17988632627,
#      'volume_24h': 16901009.5814393}},
#    'slug': 'kucoin-shares',
#    'symbol': 'KCS',
#    'tags': [],
#    'total_supply': 179939916},
#   {'circulating_supply': 99299117.1702563,
#    'cmc_rank': 62,
#    'date_added': '2016-08-12T00:00:00.000Z',
#    'id': 1343,
#    'last_updated': '2019-04-22T23:47:02.000Z',
#    'max_supply': None,
#    'name': 'Stratis',
#    'num_market_pairs': 19,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:02.000Z',
#      'market_cap': 105003518.02908385,
#      'percent_change_1h': 0.0297577,
#      'percent_change_24h': -0.143649,
#      'percent_change_7d': -0.702048,
#      'price': 1.05744664224,
#      'volume_24h': 1236578.99117324}},
#    'slug': 'stratis',
#    'symbol': 'STRAT',
#    'tags': [],
#    'total_supply': 99299117.1702563},
#   {'circulating_supply': 104056777.242561,
#    'cmc_rank': 63,
#    'date_added': '2018-09-27T00:00:00.000Z',
#    'id': 3330,
#    'last_updated': '2019-04-22T23:47:10.000Z',
#    'max_supply': None,
#    'name': 'Paxos Standard Token',
#    'num_market_pairs': 82,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x8e870d67f660d95d5be530380d0ec0bd388289e1'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:10.000Z',
#      'market_cap': 103985202.9706278,
#      'percent_change_1h': -0.137253,
#      'percent_change_24h': 0.0623839,
#      'percent_change_7d': -0.263473,
#      'price': 0.999312161362,
#      'volume_24h': 81480843.216924}},
#    'slug': 'paxos-standard-token',
#    'symbol': 'PAX',
#    'tags': [],
#    'total_supply': 105376373.69},
#   {'circulating_supply': 870502690,
#    'cmc_rank': 64,
#    'date_added': '2018-01-17T00:00:00.000Z',
#    'id': 2416,
#    'last_updated': '2019-04-22T23:47:06.000Z',
#    'max_supply': None,
#    'name': 'THETA',
#    'num_market_pairs': 30,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:06.000Z',
#      'market_cap': 97637444.75851613,
#      'percent_change_1h': -0.7915,
#      'percent_change_24h': -2.56298,
#      'percent_change_7d': -6.64051,
#      'price': 0.112162140198,
#      'volume_24h': 3741831.73086497}},
#    'slug': 'theta',
#    'symbol': 'THETA',
#    'tags': [],
#    'total_supply': 1000000000},
#   {'circulating_supply': 3470483788,
#    'cmc_rank': 65,
#    'date_added': '2017-06-28T00:00:00.000Z',
#    'id': 1759,
#    'last_updated': '2019-04-22T23:47:03.000Z',
#    'max_supply': None,
#    'name': 'Status',
#    'num_market_pairs': 83,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x744d70fdbe2ba4cf95131626614a1763df805b9e'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:03.000Z',
#      'market_cap': 91448734.77763085,
#      'percent_change_1h': -0.187682,
#      'percent_change_24h': 4.121,
#      'percent_change_7d': 5.89549,
#      'price': 0.0263504284601,
#      'volume_24h': 12794933.8698406}},
#    'slug': 'status',
#    'symbol': 'SNT',
#    'tags': [],
#    'total_supply': 6804870174},
#   {'circulating_supply': 9442244.404,
#    'cmc_rank': 66,
#    'date_added': '2015-10-06T00:00:00.000Z',
#    'id': 1087,
#    'last_updated': '2019-04-22T23:47:01.000Z',
#    'max_supply': None,
#    'name': 'Factom',
#    'num_market_pairs': 5,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:01.000Z',
#      'market_cap': 88889593.96398512,
#      'percent_change_1h': -0.304894,
#      'percent_change_24h': -0.581631,
#      'percent_change_7d': 7.71136,
#      'price': 9.41403231697,
#      'volume_24h': 329243.939779978}},
#    'slug': 'factom',
#    'symbol': 'FCT',
#    'tags': [],
#    'total_supply': 9442244.404},
#   {'circulating_supply': 87744319.8937426,
#    'cmc_rank': 67,
#    'date_added': '2017-12-24T00:00:00.000Z',
#    'id': 2308,
#    'last_updated': '2019-04-22T23:47:06.000Z',
#    'max_supply': None,
#    'name': 'Dai',
#    'num_market_pairs': 82,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x89d24a6b4ccb1b6faa2625fe562bdd9a23260359'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:06.000Z',
#      'market_cap': 87588295.19580229,
#      'percent_change_1h': -0.327657,
#      'percent_change_24h': 0.959803,
#      'percent_change_7d': 4.01204,
#      'price': 0.998221825662,
#      'volume_24h': 39397521.6136745}},
#    'slug': 'dai',
#    'symbol': 'DAI',
#    'tags': [],
#    'total_supply': 87744319.8937426},
#   {'circulating_supply': 963622000,
#    'cmc_rank': 68,
#    'date_added': '2016-11-18T00:00:00.000Z',
#    'id': 1455,
#    'last_updated': '2019-04-22T23:47:02.000Z',
#    'max_supply': None,
#    'name': 'Golem',
#    'num_market_pairs': 89,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0xa74476443119A942dE498590Fe1f2454d7D4aC0d'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:02.000Z',
#      'market_cap': 86359902.35883395,
#      'percent_change_1h': -0.156068,
#      'percent_change_24h': -3.91675,
#      'percent_change_7d': 2.6139,
#      'price': 0.0896201024456,
#      'volume_24h': 2618055.88053436}},
#    'slug': 'golem-network-tokens',
#    'symbol': 'GNT',
#    'tags': [],
#    'total_supply': 1000000000},
#   {'circulating_supply': 440711.078779516,
#    'cmc_rank': 69,
#    'date_added': '2018-01-09T00:00:00.000Z',
#    'id': 2349,
#    'last_updated': '2019-04-22T23:47:06.000Z',
#    'max_supply': None,
#    'name': 'Mixin',
#    'num_market_pairs': 7,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0xa974c709cfb4566686553a20790685a47aceaa33'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:06.000Z',
#      'market_cap': 85385916.98588683,
#      'percent_change_1h': -0.499398,
#      'percent_change_24h': -1.43605,
#      'percent_change_7d': -7.03954,
#      'price': 193.745791965,
#      'volume_24h': 1064614.43708701}},
#    'slug': 'mixin',
#    'symbol': 'XIN',
#    'tags': [],
#    'total_supply': 1000000},
#   {'circulating_supply': 505080492.343297,
#    'cmc_rank': 70,
#    'date_added': '2018-10-12T00:00:00.000Z',
#    'id': 3437,
#    'last_updated': '2019-04-22T23:47:10.000Z',
#    'max_supply': None,
#    'name': 'ABBC Coin',
# ...
#    'id': 2300,
#    'last_updated': '2019-04-22T23:47:06.000Z',
#    'max_supply': None,
#    'name': 'WAX',
#    'num_market_pairs': 32,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x39Bb259F66E1C59d5ABEF88375979b4D20D98022'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:06.000Z',
#      'market_cap': 73667369.74812773,
#      'percent_change_1h': 0.255907,
#      'percent_change_24h': -5.34552,
#      'percent_change_7d': -1.318,
#      'price': 0.0781424005571,
#      'volume_24h': 853869.09716015}},
#    'slug': 'wax',
#    'symbol': 'WAX',
#    'tags': [],
#    'total_supply': 1850000000},
#   {'circulating_supply': 2000000,
#    'cmc_rank': 80,
#    'date_added': '2016-04-18T00:00:00.000Z',
#    'id': 1229,
#    'last_updated': '2019-04-22T23:47:02.000Z',
#    'max_supply': None,
#    'name': 'DigixDAO',
#    'num_market_pairs': 23,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0xe0b7927c4af23765cb51314a0e0521a9645f0e2a'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:02.000Z',
#      'market_cap': 72045404.99780001,
#      'percent_change_1h': -5.49274,
#      'percent_change_24h': 38.2995,
#      'percent_change_7d': 88.9468,
#      'price': 36.0227024989,
#      'volume_24h': 24849426.4578976}},
#    'slug': 'digixdao',
#    'symbol': 'DGD',
#    'tags': [],
#    'total_supply': 2000000},
#   {'circulating_supply': 65729674.8711679,
#    'cmc_rank': 81,
#    'date_added': '2014-03-20T00:00:00.000Z',
#    'id': 213,
#    'last_updated': '2019-04-22T23:47:01.000Z',
#    'max_supply': None,
#    'name': 'MonaCoin',
#    'num_market_pairs': 21,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:01.000Z',
#      'market_cap': 71354774.07304223,
#      'percent_change_1h': -1.36728,
#      'percent_change_24h': -3.23998,
#      'percent_change_7d': 73.8511,
#      'price': 1.08557929448,
#      'volume_24h': 8725896.4553945}},
#    'slug': 'monacoin',
#    'symbol': 'MONA',
#    'tags': ['mineable'],
#    'total_supply': 65729674.8711679},
#   {'circulating_supply': 53252245.9943896,
#    'cmc_rank': 82,
#    'date_added': '2017-07-10T00:00:00.000Z',
#    'id': 1789,
#    'last_updated': '2019-04-22T23:47:03.000Z',
#    'max_supply': 53252246,
#    'name': 'Populous',
#    'num_market_pairs': 33,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0xd4fa1460f537bb9085d22c7bccb5dd450ef28e3a'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:03.000Z',
#      'market_cap': 71152386.73928411,
#      'percent_change_1h': -0.88212,
#      'percent_change_24h': -0.460408,
#      'percent_change_7d': -6.6473,
#      'price': 1.33613870008,
#      'volume_24h': 1614992.42002607}},
#    'slug': 'populous',
#    'symbol': 'PPT',
#    'tags': [],
#    'total_supply': 53252246},
#   {'circulating_supply': 7078400000,
#    'cmc_rank': 83,
#    'date_added': '2018-11-15T00:00:00.000Z',
#    'id': 3607,
#    'last_updated': '2019-04-22T23:47:10.000Z',
#    'max_supply': None,
#    'name': 'VestChain',
#    'num_market_pairs': 3,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x37f04d2c3ae075fad5483bb918491f656b12bdb6'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:10.000Z',
#      'market_cap': 67487647.66289818,
#      'percent_change_1h': -0.0200857,
#      'percent_change_24h': 3.15841,
#      'percent_change_7d': 9.52614,
#      'price': 0.00953430827064,
#      'volume_24h': 372224.833489419}},
#    'slug': 'vestchain',
#    'symbol': 'VEST',
#    'tags': [],
#    'total_supply': 8848000000},
#   {'circulating_supply': 1635091510.66,
#    'cmc_rank': 84,
#    'date_added': '2019-04-03T00:00:00.000Z',
#    'id': 3835,
#    'last_updated': '2019-04-22T23:47:11.000Z',
#    'max_supply': None,
#    'name': 'Orbs',
#    'num_market_pairs': 14,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0xff56cc6b1e6ded347aa0b7676c85ab0b3d08b0fa'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:11.000Z',
#      'market_cap': 67246875.14388554,
#      'percent_change_1h': -0.430054,
#      'percent_change_24h': -4.35912,
#      'percent_change_7d': 35.2164,
#      'price': 0.0411272853571,
#      'volume_24h': 7892893.12151658}},
#    'slug': 'orbs',
#    'symbol': 'ORBS',
#    'tags': [],
#    'total_supply': 10000000000},
#   {'circulating_supply': 86686.0215,
#    'cmc_rank': 85,
#    'date_added': '2018-08-10T00:00:00.000Z',
#    'id': 3144,
#    'last_updated': '2019-04-22T23:47:09.000Z',
#    'max_supply': None,
#    'name': 'ThoreCoin',
#    'num_market_pairs': 1,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x1cb3209d45b2a60b7fbca1ccdbf87f674237a4aa'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:09.000Z',
#      'market_cap': 67826396.69795372,
#      'percent_change_1h': -0.390009,
#      'percent_change_24h': 5.76093,
#      'percent_change_7d': 6.90122,
#      'price': 782.43753173,
#      'volume_24h': 96964.0503833465}},
#    'slug': 'thorecoin',
#    'symbol': 'THR',
#    'tags': [],
#    'total_supply': 100000},
#   {'circulating_supply': 109800302,
#    'cmc_rank': 86,
#    'date_added': '2017-03-22T00:00:00.000Z',
#    'id': 1586,
#    'last_updated': '2019-04-22T23:47:02.000Z',
#    'max_supply': None,
#    'name': 'Ark',
#    'num_market_pairs': 20,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:02.000Z',
#      'market_cap': 65810523.525521204,
#      'percent_change_1h': -0.450718,
#      'percent_change_24h': -0.801042,
#      'percent_change_7d': -3.1864,
#      'price': 0.599365596695,
#      'volume_24h': 399292.826932178}},
#    'slug': 'ark',
#    'symbol': 'ARK',
#    'tags': [],
#    'total_supply': 141050302},
#   {'circulating_supply': 330999999.986,
#    'cmc_rank': 87,
#    'date_added': '2017-12-21T00:00:00.000Z',
#    'id': 2299,
#    'last_updated': '2019-04-22T23:47:06.000Z',
#    'max_supply': 1000000000,
#    'name': 'aelf',
#    'num_market_pairs': 61,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0xbf2179859fc6d5bee9bf9158632dc51678a4100e'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:06.000Z',
#      'market_cap': 64678802.86033134,
#      'percent_change_1h': -0.0638834,
#      'percent_change_24h': 4.99309,
#      'percent_change_7d': 6.89211,
#      'price': 0.195404238257,
#      'volume_24h': 14093168.9611277}},
#    'slug': 'aelf',
#    'symbol': 'ELF',
#    'tags': [],
#    'total_supply': 879999999.986},
#   {'circulating_supply': 484450000,
#    'cmc_rank': 88,
#    'date_added': '2017-11-01T00:00:00.000Z',
#    'id': 2135,
#    'last_updated': '2019-04-22T23:47:05.000Z',
#    'max_supply': 484450000,
#    'name': 'Revain',
#    'num_market_pairs': 21,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x48f775efbe4f5ece6e0df2f7b5932df56823b990'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:05.000Z',
#      'market_cap': 62920676.36822145,
#      'percent_change_1h': -0.554319,
#      'percent_change_24h': 1.89815,
#      'percent_change_7d': 4.80971,
#      'price': 0.129880640661,
#      'volume_24h': 1714540.6273867}},
#    'slug': 'revain',
#    'symbol': 'R',
#    'tags': [],
#    'total_supply': 484450000},
#   {'circulating_supply': 60783375.31,
#    'cmc_rank': 89,
#    'date_added': '2018-10-05T00:00:00.000Z',
#    'id': 3306,
#    'last_updated': '2019-04-22T23:47:09.000Z',
#    'max_supply': None,
#    'name': 'Gemini Dollar',
#    'num_market_pairs': 60,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x056Fd409E1d7A124BD7017459dFEa2F387b6d5Cd'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:09.000Z',
#      'market_cap': 61105248.2532927,
#      'percent_change_1h': -0.200105,
#      'percent_change_24h': 0.353181,
#      'percent_change_7d': 0.924081,
#      'price': 1.00529541082,
#      'volume_24h': 10155784.0981226}},
#    'slug': 'gemini-dollar',
#    'symbol': 'GUSD',
#    'tags': [],
#    'total_supply': 60783375.31},
#   {'circulating_supply': 69311847.9494196,
#    'cmc_rank': 90,
#    'date_added': '2017-10-25T00:00:00.000Z',
#    'id': 2092,
#    'last_updated': '2019-04-22T23:47:05.000Z',
#    'max_supply': None,
#    'name': 'NULS',
#    'num_market_pairs': 24,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:05.000Z',
#      'market_cap': 59411929.97861841,
#      'percent_change_1h': -0.418386,
#      'percent_change_24h': 1.90392,
#      'percent_change_7d': 0.0510293,
#      'price': 0.857168460174,
#      'volume_24h': 8201530.49502635}},
#    'slug': 'nuls',
#    'symbol': 'NULS',
#    'tags': ['mineable'],
#    'total_supply': 103904024.707577},
#   {'circulating_supply': 452552412,
#    'cmc_rank': 91,
#    'date_added': '2014-04-28T00:00:00.000Z',
#    'id': 291,
#    'last_updated': '2019-04-22T23:47:01.000Z',
#    'max_supply': None,
#    'name': 'MaidSafeCoin',
#    'num_market_pairs': 6,
#    'platform': {'id': 83,
#     'name': 'Omni',
#     'slug': 'omni',
#     'symbol': 'OMNI',
#     'token_address': '3'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:01.000Z',
#      'market_cap': 59007519.188108474,
#      'percent_change_1h': 1.18868,
#      'percent_change_24h': -5.24537,
#      'percent_change_7d': -1.22211,
#      'price': 0.13038825476,
#      'volume_24h': 568050.42956031}},
#    'slug': 'maidsafecoin',
#    'symbol': 'MAID',
#    'tags': [],
#    'total_supply': 452552412},
#   {'circulating_supply': 7329672.32977799,
#    'cmc_rank': 92,
#    'date_added': '2016-10-06T00:00:00.000Z',
#    'id': 1414,
#    'last_updated': '2019-04-22T23:47:02.000Z',
#    'max_supply': 21400000,
#    'name': 'Zcoin',
#    'num_market_pairs': 34,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:02.000Z',
#      'market_cap': 58704897.0863179,
#      'percent_change_1h': -0.0915131,
#      'percent_change_24h': 2.2384,
#      'percent_change_7d': 1.52248,
#      'price': 8.00921165982,
#      'volume_24h': 1034218.66565218}},
#    'slug': 'zcoin',
#    'symbol': 'XZC',
#    'tags': ['mineable'],
#    'total_supply': 21400000},
#   {'circulating_supply': 1050141509.426,
#    'cmc_rank': 93,
#    'date_added': '2017-09-17T00:00:00.000Z',
#    'id': 1966,
#    'last_updated': '2019-04-22T23:47:04.000Z',
#    'max_supply': None,
#    'name': 'Decentraland',
#    'num_market_pairs': 59,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x0f5d2fb29fb7d3cfee444a200298f468908cc942'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:04.000Z',
#      'market_cap': 58563117.8062241,
#      'percent_change_1h': 0.571117,
#      'percent_change_24h': 1.25554,
#      'percent_change_7d': 6.14812,
#      'price': 0.0557668821588,
#      'volume_24h': 5977609.08202351}},
#    'slug': 'decentraland',
#    'symbol': 'MANA',
#    'tags': [],
#    'total_supply': 2644403343.1583},
#   {'circulating_supply': 300724162,
#    'cmc_rank': 94,
#    'date_added': '2017-10-18T00:00:00.000Z',
#    'id': 2062,
#    'last_updated': '2019-04-22T23:47:05.000Z',
#    'max_supply': None,
#    'name': 'Aion',
#    'num_market_pairs': 23,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:05.000Z',
#      'market_cap': 58115265.5283216,
#      'percent_change_1h': -1.45325,
#      'percent_change_24h': 4.23366,
#      'percent_change_7d': 10.2975,
#      'price': 0.193251068161,
#      'volume_24h': 2978244.25937862}},
#    'slug': 'aion',
#    'symbol': 'AION',
#    'tags': ['mineable'],
#    'total_supply': 300724162},
#   {'circulating_supply': 15195573.9579747,
#    'cmc_rank': 95,
#    'date_added': '2018-01-31T00:00:00.000Z',
#    'id': 2492,
#    'last_updated': '2019-04-22T23:47:07.000Z',
#    'max_supply': None,
#    'name': 'Elastos',
#    'num_market_pairs': 17,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:07.000Z',
#      'market_cap': 55938542.31621515,
#      'percent_change_1h': -1.22031,
#      'percent_change_24h': -6.36329,
#      'percent_change_7d': -2.16038,
#      'price': 3.68123918655,
#      'volume_24h': 3388882.27003377}},
#    'slug': 'elastos',
#    'symbol': 'ELA',
#    'tags': ['mineable'],
#    'total_supply': 34367335.4514697},
#   {'circulating_supply': 43529780.865052,
#    'cmc_rank': 96,
#    'date_added': '2017-08-20T00:00:00.000Z',
#    'id': 1903,
#    'last_updated': '2019-04-22T23:47:04.000Z',
#    'max_supply': 84000000,
#    'name': 'HyperCash',
#    'num_market_pairs': 21,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:04.000Z',
#      'market_cap': 56696113.915465206,
#      'percent_change_1h': -0.176963,
#      'percent_change_24h': -0.325409,
#      'percent_change_7d': -7.69023,
#      'price': 1.3024672486,
#      'volume_24h': 1451450.08352291}},
#    'slug': 'hypercash',
#    'symbol': 'HC',
#    'tags': ['mineable'],
#    'total_supply': 43529780.865052},
#   {'circulating_supply': 45500000,
#    'cmc_rank': 97,
#    'date_added': '2017-08-23T00:00:00.000Z',
#    'id': 1908,
#    'last_updated': '2019-04-22T23:47:04.000Z',
#    'max_supply': 100000000,
#    'name': 'Nebulas',
#    'num_market_pairs': 19,
#    'platform': None,
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:04.000Z',
#      'market_cap': 56004658.989369996,
#      'percent_change_1h': -0.223216,
#      'percent_change_24h': 2.23371,
#      'percent_change_7d': -5.26798,
#      'price': 1.23087162614,
#      'volume_24h': 7979189.68709969}},
#    'slug': 'nebulas-token',
#    'symbol': 'NAS',
#    'tags': [],
#    'total_supply': 100000000},
#   {'circulating_supply': 828954239.778787,
#    'cmc_rank': 98,
#    'date_added': '2017-08-30T00:00:00.000Z',
#    'id': 1934,
#    'last_updated': '2019-04-22T23:47:04.000Z',
#    'max_supply': None,
#    'name': 'Loopring',
#    'num_market_pairs': 33,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0xef68e7c694f40c8202821edf525de3782458639f'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:04.000Z',
#      'market_cap': 55793334.60832932,
#      'percent_change_1h': -0.524908,
#      'percent_change_24h': -1.2133,
#      'percent_change_7d': -6.37571,
#      'price': 0.0673056870102,
#      'volume_24h': 15130940.7259922}},
#    'slug': 'loopring',
#    'symbol': 'LRC',
#    'tags': [],
#    'total_supply': 1374955751.72106},
#   {'circulating_supply': 780022998.084613,
#    'cmc_rank': 99,
#    'date_added': '2018-03-14T00:00:00.000Z',
#    'id': 2588,
#    'last_updated': '2019-04-22T23:47:07.000Z',
#    'max_supply': None,
#    'name': 'Loom Network',
#    'num_market_pairs': 50,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0xa4e8c3ec456107ea67d3075bf9e3df3a75823db0'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:07.000Z',
#      'market_cap': 54296139.62459875,
#      'percent_change_1h': -0.0876598,
#      'percent_change_24h': 0.210379,
#      'percent_change_7d': 3.91425,
#      'price': 0.0696083830322,
#      'volume_24h': 1445568.31559947}},
#    'slug': 'loom-network',
#    'symbol': 'LOOM',
#    'tags': [],
#    'total_supply': 1000000000},
#   {'circulating_supply': 404852066.959772,
#    'cmc_rank': 100,
#    'date_added': '2017-11-01T00:00:00.000Z',
#    'id': 2132,
#    'last_updated': '2019-04-22T23:47:05.000Z',
#    'max_supply': None,
#    'name': 'Power Ledger',
#    'num_market_pairs': 47,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'slug': 'ethereum',
#     'symbol': 'ETH',
#     'token_address': '0x595832f8fc6bf59c85c527fec3740a1b7a361269'},
#    'quote': {'USD': {'last_updated': '2019-04-22T23:47:05.000Z',
#      'market_cap': 51463631.721652746,
#      'percent_change_1h': -0.224614,
#      'percent_change_24h': -1.13854,
#      'percent_change_7d': 8.48667,
#      'price': 0.127117127271,
#      'volume_24h': 2959660.63311921}},
#    'slug': 'power-ledger',
#    'symbol': 'POWR',
#    'tags': [],
#    'total_supply': 1000000000}],
#  'status': {'credit_count': 1,
#   'elapsed': 13,
#   'error_code': 0,
#   'error_message': None,
#   'timestamp': '2019-04-22T23:47:51.909Z'}}

# %% [markdown]
# ## Store data in Pretty Table

# %%
for currency in cryptodata:
    curr_name = currency['name']
    curr_price = currency['quote']['USD']['price']
    curr_change_1h = currency['quote']['USD']['percent_change_1h']
    curr_change_24h = currency['quote']['USD']['percent_change_24h']
    curr_change_7d = currency['quote']['USD']['percent_change_7d']
    tableobj.add_row([curr_name, curr_price, curr_change_1h, curr_change_24h, curr_change_7d])

# %% [markdown]
# ## Create External Field names and assign as column names in Pretty table

# %%
tableobj.field_names =  ["Currency Name", "Currency Price", "Currency 1h Change", "Currency 24h change", "Currency 7d change"]

# %%
print(tableobj)
# Out:
# +-----------------------+-------------------+--------------------+---------------------+--------------------+
# |     Currency Name     |   Currency Price  | Currency 1h Change | Currency 24h change | Currency 7d change |
# +-----------------------+-------------------+--------------------+---------------------+--------------------+
# |        Bitcoin        |   5395.93482863   |     -0.301241      |       1.67833       |      6.45182       |
# |        Ethereum       |   171.679679233   |     -0.625783      |       1.00709       |      6.29453       |
# |          XRP          |   0.323826259932  |     -0.338398      |       0.631114      |      1.09363       |
# |      Bitcoin Cash     |   293.223052743   |     -0.500709      |       1.04336       |      -6.30347      |
# |          EOS          |   5.24829958966   |     -0.663814      |       0.354616      |      -2.10802      |
# |        Litecoin       |    77.010881659   |     -0.540749      |      0.0512766      |      -2.01171      |
# |      Binance Coin     |   23.9180267057   |      1.23429       |      -0.876029      |      25.1995       |
# |         Tether        |    1.0066692901   |     0.0122913      |      0.0514391      |      0.477698      |
# |        Stellar        |   0.113510122924  |     -0.407042      |       1.17453       |     -0.158736      |
# |        Cardano        |   0.078328552124  |     -0.202013      |       5.94131       |      -4.49479      |
# |          TRON         |  0.0251768797514  |      -0.11395      |       0.661038      |      -4.66225      |
# |         Monero        |   68.5850900392   |     -0.439058      |      0.0814216      |      6.20146       |
# |          Dash         |   122.623185733   |     -0.215139      |       0.932616      |      3.50391       |
# |       Bitcoin SV      |   57.7320918097   |      -1.05453      |       2.02989       |      -2.33204      |
# |         Tezos         |   1.34485384103   |     -0.295701      |       1.22089       |      25.5726       |
# |          IOTA         |   0.309887386353  |     -0.020932      |       1.26663       |       1.8617       |
# |          NEO          |   10.8219875674   |     -0.496782      |       2.77108       |      0.943441      |
# |    Ethereum Classic   |   5.94200683493   |     -0.368996      |       0.477218      |      -3.60662      |
# |        Ontology       |   1.23671503213   |      0.439603      |       0.54443       |      -4.37433      |
# |         Maker         |    606.92259523   |     -0.261892      |       0.506255      |      -3.84341      |
# |          NEM          |  0.0640887182307  |      -0.39575      |       1.31256       |      -1.0292       |
# | Basic Attention Token |    0.3981570912   |     -0.637878      |       -11.0222      |      35.2271       |
# |         Zcash         |   69.1191339374   |     -0.201401      |       1.12907       |      3.08441       |
# |    Crypto.com Chain   |  0.0816901512349  |       1.5627       |       -1.72098      |      4.87336       |
# |        VeChain        |  0.0069982237727  |    -0.00714884     |       2.70428       |      2.78171       |
# |        Dogecoin       |  0.00280019457838 |      -0.35626      |       1.56876       |      0.212099      |
# |      Bitcoin Gold     |   16.9397232967   |     -0.527219      |       1.58411       |       3.4235       |
# |         Waves         |   2.63420406348   |     -0.375385      |       1.08876       |     0.0584478      |
# |        OmiseGO        |    1.8736185956   |     -0.174754      |       0.690785      |      0.799532      |
# |        USD Coin       |   1.00418649464   |     -0.0834506     |       0.252437      |      0.36061       |
# |         Augur         |   22.7917184467   |      1.63758       |       9.52372       |       20.345       |
# |         Decred        |   25.6377773348   |     -0.184575      |       0.94828       |      6.12032       |
# |          Qtum         |    2.7641105848   |     -0.523838      |        1.8344       |      -2.49351      |
# |          Nano         |   1.76693619808   |      0.239493      |       5.05872       |      17.0954       |
# |          Lisk         |   1.99824704345   |     -0.415115      |       0.582984      |      2.46433       |
# |       Ravencoin       |  0.0618465547718  |      -0.18839      |       -1.69884      |      7.08135       |
# |        TrueUSD        |   1.00449312484   |     -0.0633392     |      -0.0660092     |      0.060028      |
# |    Bitcoin Diamond    |   1.07022877901   |     -0.0424643     |       1.25025       |      0.504274      |
# |          ICON         |   0.408891520932  |      -2.01443      |       13.3825       |      14.2961       |
# |          Holo         |  0.00139140456254 |     -0.367233      |       0.410204      |       12.266       |
# |           0x          |   0.312254572587  |     -0.624202      |      -0.480959      |      0.679167      |
# |        Zilliqa        |  0.0210280733245  |     -0.474255      |      -0.0229366     |      1.69621       |
# |       Chainlink       |   0.497051313849  |      -0.29253      |      -0.268101      |      0.617736      |
# |        Bytecoin       | 0.000900673916611 |     -0.399337      |       1.48414       |      1.32331       |
# |       BitShares       |  0.0612151665695  |     -0.226763      |      -0.225429      |      0.283884      |
# |          IOST         |  0.0134991414901  |     -0.796345      |       -2.60613      |      5.45418       |
# |       BitTorrent      | 0.000718901833917 |      0.155679      |       -0.28265      |      -3.45906      |
# |        DigiByte       |  0.0129915961721  |      -0.80656      |       1.78172       |      0.974308      |
# |       Aeternity       |   0.562528313498  |      -1.00377      |       2.71126       |       4.514        |
# |       Enjin Coin      |   0.189721966059  |     -0.489919      |      -0.476284      |      24.9572       |
# |        Pundi X        | 0.000695040221965 |      0.53915       |       0.360731      |      1.57168       |
# |         Verge         |   0.00843596334   |     -0.591258      |       2.54424       |      2.24416       |
# |         Steem         |   0.417114437964  |     -0.0149815     |       0.335373      |      0.895141      |
# |        Siacoin        |  0.00306266646197 |     -0.516721      |       4.28616       |     -0.400425      |
# |      Huobi Token      |   2.45560702418   |     -0.760358      |      -0.383464      |      7.90013       |
# |         Komodo        |   1.08675216573   |     -0.847724      |       0.399668      |      5.31083       |
# |         Bytom         |   0.110792903984  |     -0.375307      |       0.464654      |      -7.14828      |
# |         Aurora        |  0.0163970394639  |      1.36008       |       1.66415       |      -1.5981       |
# |     Maximine Coin     |   0.065617786533  |      -1.52383      |       -8.80889      |      -18.2111      |
# |      Waltonchain      |   2.59012595864   |       -0.769       |       1.31191       |      24.6043       |
# |     KuCoin Shares     |   1.17933863205   |     -0.102289      |      -0.392765      |       4.1148       |
# |        Stratis        |   1.05563184996   |      0.005771      |      -0.309121      |     -0.871017      |
# |  Paxos Standard Token |    1.0002056619   |     -0.050596      |       0.156765      |     -0.174895      |
# |         THETA         |   0.112318084996  |     -0.729019      |       -2.43525      |      -6.46707      |
# |         Status        |  0.0264043452091  |      0.115054      |       4.36335       |      6.11759       |
# |         Factom        |   9.41140495367   |     -0.289617      |      -0.572579      |      7.66512       |
# |          Dai          |   0.997769761187  |     -0.472041      |       0.945003      |      3.97823       |
# |         Golem         |  0.0896235010006  |     -0.110958      |       -3.84428      |      2.59732       |
# |         Mixin         |   193.882215236   |      -0.41556      |       -1.33158      |      -6.99561      |
# |       ABBC Coin       |   0.16547103443   |      -2.24053      |       -3.30659      |      -17.5272      |
# |    Digitex Futures    |   0.110089669148  |      -2.79087      |       -3.16381      |      -2.87767      |
# |         Ardor         |  0.0816725406099  |     -0.199184      |       1.59153       |      6.13391       |
# |     Insight Chain     |   0.233470822932  |     0.0963639      |       -1.3805       |      -11.8649      |
# |        GXChain        |   1.34521377943   |      -0.19652      |       1.30532       |      2.31709       |
# |       Crypto.com      |   5.03710839823   |     -0.995733      |       -2.41101      |       25.302       |
# |       Cryptonex       |   1.37476598684   |     -0.587687      |       -4.53629      |      0.325016      |
# |        Qubitica       |   26.6855286202   |     -0.354762      |       0.155195      |      3.28634       |
# |      Project Pai      |  0.0510097526273  |     -0.746362      |       -1.57606      |      -9.14726      |
# |          WAX          |  0.0781271594763  |      0.158034      |       -5.34773      |      -1.36956      |
# |        DigixDAO       |   36.2664532962   |      -5.0714       |       39.2898       |      90.1926       |
# |        MonaCoin       |   1.08575721562   |      -1.35135      |       -3.41372      |      73.8717       |
# |        Populous       |   1.33611320816   |     -0.682526      |      -0.466561      |      -6.64559      |
# |          Orbs         |  0.0417390062218  |      0.926915      |       -2.93007      |      37.2793       |
# |       VestChain       |  0.00953150740787 |     -0.100571      |       3.16036       |      9.49405       |
# |       ThoreCoin       |   782.218487809   |     -0.374805      |       5.53563       |      6.87422       |
# |          Ark          |   0.598639186551  |     -0.464548      |      -0.912934      |      -3.29448      |
# |          aelf         |   0.195484134046  |     0.0235656      |       5.07835       |      6.93271       |
# |         Revain        |   0.130339592901  |     0.0645511      |       2.24377       |       5.1723       |
# |     Gemini Dollar     |   1.00467943434   |      -0.21496      |       0.282967      |      0.864375      |
# |          NULS         |   0.857895592674  |     -0.308163      |        2.0076       |      0.151738      |
# |      MaidSafeCoin     |   0.13040057468   |       1.4978       |       -5.22203      |      -1.22189      |
# |         Zcoin         |   8.00033893977   |     0.0100647      |       2.13217       |      1.41683       |
# |      Decentraland     |  0.0558564220956  |      0.872687      |       1.40132       |      6.33659       |
# |          Aion         |   0.193292637062  |      -1.41652      |       4.32364       |      10.3196       |
# |        Elastos        |   3.81191986302   |      1.90763       |       -3.04966      |      1.31016       |
# |       HyperCash       |   1.30275937301   |      -0.08024      |      -0.320436      |      -7.67419      |
# |        Nebulas        |   1.23138067829   |     0.0118619      |       2.27469       |      -5.2575       |
# |        Loopring       |  0.0675340104147  |     -0.245456      |      -0.863946      |      -6.07621      |
# |      Loom Network     |  0.0695577233388  |     -0.0811951     |       0.15052       |       3.8348       |
# |          PIVX         |   0.903352765419  |     -0.339612      |      -0.832813      |      -2.88213      |
# +-----------------------+-------------------+--------------------+---------------------+--------------------+

# %% [markdown]
# ## Store data in Text File format

# %%
table_txt = tableobj.get_string()
with open('output.txt', 'w') as file:
    file.write(table_txt)
